# %%
from bs4 import BeautifulSoup
import requests
import re
import datetime
from tqdm import tqdm
import sys

# 페이지 url 형식에 맞게 바꾸어 주는 함수 만들기
  #입력된 수를 1, 11, 21, 31 ...만들어 주는 함수
def makePgNum(num):
    if num == 1:
        return num
    elif num == 0:
        return num+1
    else:
        return num+9*(num-1)

# 크롤링할 url 생성하는 함수 만들기(검색어, 크롤링 시작 페이지, 크롤링 종료 페이지)

def makeUrl(search, start_pg, end_pg):
    if start_pg == end_pg:
        start_page = makePgNum(start_pg)
        url = "https://search.naver.com/search.naver?where=news&sm=tab_pge&query=" + search + "&start=" + str(start_page)
        print("생성url: ", url)
        return url
    else:
        urls = []
        for i in range(start_pg, end_pg + 1):
            page = makePgNum(i)
            url = "https://search.naver.com/search.naver?where=news&sm=tab_pge&query=" + search + "&start=" + str(page)
            urls.append(url)
        print("생성url: ", urls)
        return urls    

# html에서 원하는 속성 추출하는 함수 만들기 (기사, 추출하려는 속성값)
def news_attrs_crawler(articles,attrs):
    attrs_content=[]
    for i in articles:
        attrs_content.append(i.attrs[attrs])
    return attrs_content

# ConnectionError방지
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) Chrome/98.0.4758.102"}

#html생성해서 기사크롤링하는 함수 만들기(url): 링크를 반환
def articles_crawler(url):
    #html 불러오기
    original_html = requests.get(i,headers=headers)
    html = BeautifulSoup(original_html.text, "html.parser")

    url_naver = html.select("div.group_news > ul.list_news > li div.news_area > div.news_info > div.info_group > a.info")
    url = news_attrs_crawler(url_naver,'href')
    return url


#####뉴스크롤링 시작#####

#검색어 입력
search = input("검색할 키워드를 입력해주세요:")
#검색 시작할 페이지 입력
page = int(input("\n크롤링할 시작 페이지를 입력해주세요. ex)1(숫자만입력):")) # ex)1 =1페이지,2=2페이지...
print("\n크롤링할 시작 페이지: ",page,"페이지")   
#검색 종료할 페이지 입력
page2 = int(input("\n크롤링할 종료 페이지를 입력해주세요. ex)1(숫자만입력):")) # ex)1 =1페이지,2=2페이지...
print("\n크롤링할 종료 페이지: ",page2,"페이지")   


# naver url 생성
url = makeUrl(search,page,page2)

#뉴스 크롤러 실행
news_titles = []
news_url =[]
news_contents =[]
news_dates = []
for i in url:
    url = articles_crawler(url)
    news_url.append(url)


#제목, 링크, 내용 1차원 리스트로 꺼내는 함수 생성
def makeList(newlist, content):
    for i in content:
        for j in i:
            newlist.append(j)
    return newlist

    
#제목, 링크, 내용 담을 리스트 생성
news_url_1 = []

#1차원 리스트로 만들기(내용 제외)
makeList(news_url_1,news_url)

#NAVER 뉴스만 남기기
final_urls = []
for i in tqdm(range(len(news_url_1))):
    if "news.naver.com" in news_url_1[i]:
        final_urls.append(news_url_1[i])
    else:
        pass

# 뉴스 내용 크롤링

for i in tqdm(final_urls):
    #각 기사 html get하기
    news = requests.get(i,headers=headers)
    news_html = BeautifulSoup(news.text,"html.parser")

    # 뉴스 제목 가져오기
    title = news_html.select_one("#ct > div.media_end_head.go_trans > div.media_end_head_title > h2")
    if title == None:
        title = news_html.select_one("#content > div.end_ct > div > h2")
    
    # 뉴스 본문 가져오기
    content = news_html.select("div#dic_area")
    if content == []:
        content = news_html.select("#articeBody")

    # 기사 텍스트만 가져오기
    # list합치기
    content = ''.join(str(content))

    # html태그제거 및 텍스트 다듬기
    pattern1 = '<[^>]*>'
    title = re.sub(pattern=pattern1, repl='', string=str(title))
    content = re.sub(pattern=pattern1, repl='', string=content)
    pattern2 = """[\n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction _flash_removeCallback() {}"""
    content = content.replace(pattern2, '')

    news_titles.append(title)
    news_contents.append(content)

    try:
        html_date = news_html.select_one("div#ct> div.media_end_head.go_trans > div.media_end_head_info.nv_notrans > div.media_end_head_info_datestamp > div > span")
        news_date = html_date.attrs['data-date-time']
    except AttributeError:
        news_date = news_html.select_one("#content > div.end_ct > div > div.article_info > span > em")
        news_date = re.sub(pattern=pattern1,repl='',string=str(news_date))
    # 날짜 가져오기
    news_dates.append(news_date)

print("검색된 기사 갯수: 총 ",(page2+1-page)*10,'개')
# print("\n[뉴스 제목]")
# print(news_titles)
# print("\n[뉴스 링크]")
# print(final_urls)
# print("\n[뉴스 내용]")
# #print(news_contents)

# print('news_title: ',len(news_titles))
# print('news_url: ',len(final_urls))
# print('news_contents: ',len(news_contents))
# print('news_dates: ',len(news_dates))

# ###데이터 프레임으로 만들기###
# import pandas as pd

# #데이터 프레임 만들기
# news_df = pd.DataFrame({'date':news_dates,'title':news_titles,'link':final_urls,'content':news_contents})

# #중복 행 지우기
# news_df = news_df.drop_duplicates(keep='first',ignore_index=True)
# print("중복 제거 후 행 개수: ",len(news_df))

# #데이터 프레임 저장
# now = datetime.datetime.now() 
# news_df.to_csv("economic_data.csv",encoding='utf-8-sig',index=False)
# news_df.to_csv('{}_{}.csv'.format(search,now.strftime('%Y%m%d_%H시%M분%S초')),encoding='utf-8-sig',index=False)
# Out:
# 검색할 키워드를 입력해주세요:연예
#
# 크롤링할 시작 페이지를 입력해주세요. ex)1(숫자만입력):1
#
# 크롤링할 시작 페이지:  1 페이지
#
# 크롤링할 종료 페이지를 입력해주세요. ex)1(숫자만입력):2000
#
# 크롤링할 종료 페이지:  2000 페이지
# 생성url:  ['https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=1', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=11', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=21', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=31', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=41', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=51', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=61', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=71', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=81', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=91', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=101', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=111', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=121', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=131', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=141', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=151', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=161', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=171', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=181', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=191', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=201', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=211', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=221', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=231', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=241', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=251', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=261', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=271', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=281', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=291', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=301', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=311', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=321', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=331', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=341', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=351', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=361', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=371', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=381', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=391', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=401', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=411', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=421', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=431', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=441', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=451', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=461', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=연예&start=471', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query ...
# 100%|██████████| 36948/36948 [00:00<00:00, 2597746.15it/s]
# 100%|██████████| 16948/16948 [1:10:38<00:00,  4.00it/s]
# 검색된 기사 갯수: 총  20000 개

# %%
###데이터 프레임으로 만들기###
import pandas as pd

#데이터 프레임 만들기
news_df = pd.DataFrame({'date':news_dates,'title':news_titles,'link':final_urls,'content':news_contents})

#중복 행 지우기
news_df = news_df.drop_duplicates(keep='first',ignore_index=True)
print("중복 제거 후 행 개수: ",len(news_df))

#데이터 프레임 저장
now = datetime.datetime.now() 
news_df.to_csv("enter_data.csv",encoding='utf-8-sig',index=False)
#news_df.to_csv('{}_{}.csv'.format(search,now.strftime('%Y%m%d_%H시%M분%S초')),encoding='utf-8-sig',index=False)
# Out:
# 중복 제거 후 행 개수:  2785

# %%
# 간단한 전처리
def clean_text(txt):
    txt = txt.replace('\n',' ')
    txt = txt.replace('\r',' ')    
    txt = txt.replace('=','')
    txt = txt.replace('\"','')   
    txt = txt.replace('\'','')
    txt = txt.replace(',','')
    txt = txt.replace('..','')
    txt = txt.replace('...','')
    txt = txt.replace('”','')
    txt = txt.replace('.','. ')
    txt = txt.replace('  ',' ')
    txt = txt.replace('  ',' ')    
    txt = txt.replace('  ',' ')   
    txt = txt.replace('  ',' ')           
    txt = txt.replace('  ',' ')
    txt = txt.replace('  ',' ')    
    txt = txt.replace('  ',' ')   
    txt = txt.replace('  ',' ')
    txt = txt.replace('[','')
    txt = txt.replace(']','')
    return txt.strip()

# %%
#df['A'] = df['A'].apply(add_2)
news_df['content'] = news_df['content'].apply(clean_text)
news_df['title'] = news_df['title'].apply(clean_text)

# %%
pattens = ["[34569][0-9]{3}[\;.\;-\; ][0-9]{4}[\;.\;-\; ][0-9]{4}[\;.\;-\; ][0-9]{4}",
           "[0-9]{2,3}[\:\s\;.\;,\;-;)][0-9]{3,4}[\:\s\;.\;,\;-][0-9]{4}",
           "[0-9]{1}[0-9]{1}[\W]?[0-1]{1}[0-9]{1}[\W]?[0-3]{1}[\W]?[0-9]{1}[\W]?[1-4]{1}[\W]?[0-9]{1}[\W]?[0-9]{1}[\W]?[0-9]{1}[\W]?[0-9]{1}[\W]?[0-9]{1}[\W]?[0-9]{1}",
           "[0-9]{2}[\:\s\;.\;,\;-][0-9]{2}[\:\s\;.\;,\;-][0-9]{6}|[0-9]{3}[\:\s\;.\;,\;-]([0-9]{5,6}[\:\s\;.\;,\;-][0-9]{3}|[0-9]{6}[\:\s\;.\;,\;-][0-9]{5}|[0-9]{2,3}[\:\s\;.\;,\;-][0-9]{6}|[0-9]{2}[\:\s\;.\;,\;-][0-9]{7}|[0-9]{2}[\:\s\;.\;,\;-][0-9]{4,6}[\:\s\;.\;,\;-][0-9]|[0-9]{5}[\:\s\;.\;,\;-][0-9]{3}[\:\s\;.\;,\;-][0-9]{2}|[0-9]{2}[\:\s\;.\;,\;-][0-9]{5}[\:\s\;.\;,\;-][0-9]{3}|[0-9]{4}[\:\s\;.\;,\;-][0-9]{4}[\:\s\;.\;,\;-][0-9]{3}|[0-9]{6}[\:\s\;.\;,\;-][0-9]{2}[\:\s\;.\;,\;-][0-9]{3}|[0-9]{2}[\:\s\;.\;,\;-][0-9]{2}[\:\s\;.\;,\;-][0-9]{7})|[0-9]{4}[\:\s\;.\;,\;-]([0-9]{3}[\:\s\;.\;,\;-][0-9]{6}|[0-9]{2}[\:\s\;.\;,\;-][0-9]{6}[\:\s\;.\;,\;-][0-9])|[0-9]{5}[\:\s\;.\;,\;-][0-9]{2}[\:\s\;.\;,\;-][0-9]{6}|[0-9]{6}[\:\s\;.\;,\;-][0-9]{2}[\:\s\;.\;,\;-][0-9]{5,6}"
           ]

filters = []
for p in pattens:
    filters.append(re.compile(p))

# %%
import nltk
nltk.download('punkt')
sentences = []

for raw_text in news_df['content']:
    try:
        docs = nltk.sent_tokenize(clean_text(raw_text))
        #print(docs)
        for txt in docs:
            if txt.find('▶') > -1 or txt.find('@') > -1 or txt.find('ⓒ') > -1: 
                pass
            else:
                txt = txt.strip()
                if len(txt) > 40:
                    #ok = True
                    #for f in filters:
                    #    if len(f.findall(txt)) > 0:
                    #        ok = False
                    #        print('fitered:',txt)
                    #if ok:
                    if any(chr.isdigit() for chr in txt):
                        pass
                    else:
                        sentences.append(txt)
    except KeyboardInterrupt as ki:
        raise ki        
    except:
        print("Unexpected error:", sys.exc_info()[0])
# Out:
# [nltk_data] Downloading package punkt to /Users/suminbae/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df3 = pd.DataFrame({'sentence':sentences})

# %%
df3.iloc[10]['sentence']
# Out:
# '/사진유튜브 채널 튀르키예즈온더블럭개그맨 이용진이 SNS 게시물을 삭제하는 연예인들을 저격했다.'

# %%
df3.to_csv("2000개page_연예롤링센텐스.csv")

# %%
len(df3)
# Out:
# 18125

# %%
df3
# Out:
#                                                 sentence
# 0         김현중은 힘든 시기에 만난 연인과 결혼식은 생략하고 혼인신고로 부부의 연을 맺었다.
# 1      당시 소속사는 어려운 시국임을 감안해 예식 등의 절차는 생략하게 됐다면서 일반인 배...
# 2      그는 다가오는 연말 시상식에서 전현무가 연예 대상을 수상할 수 있을지 점괘를 보기 ...
# 3      하지만 예상치 못한 카드에 이국주가 의아해하자 전현무는 숨겨왔던 속마음을 고백하며 ...
# 4      과거 동업자 제보 히틀러 저서 나의 투쟁 읽었다고 대놓고 말해히틀러와 나치가 독일 ...
# ...                                                  ...
# 18120  ‘오버 더 톱’은 전국의 팔씨름 고수들이 모여 오직 팔 힘 하나로 대한민국 팔씨름 ...
# 18121  형사록은 한 통의 전화와 함께 동료를 죽인 살인 용의자가 된 형사가 정체불명의 협박...
# 18122  다음 달 비연예인 신부와 결혼하는 이학주는 또 “앞으로 더 안정적으로 연기를 열심히...
# 18123  ‘형사록’은 한 통의 전화와 함께 동료를 죽인 살인 용의자가 된 형사가 정체불명의 ...
# 18124  이학주는 이 작품에서 김택록(이성민 분)을 동경해 금오경찰서에 온 낙하산 신입 형사...
#
# [18125 rows x 1 columns]
